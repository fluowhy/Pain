# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("../dataset/SA001/SA001_D2.txt")
data_7 = np.genfromtxt("../dataset/SA001/SA001_D2_7.txt")
data_8 = np.genfromtxt("../dataset/SA001/SA001_D2_8.txt")
data_9 = np.genfromtxt("../dataset/SA001/SA001_D2_9.txt")

# %%
plt.figure()
plt.plot(np.hstack((data_7, data_8, data_9))[0])

# %%
data_7 -= data_7.mean(axis=1).reshape(-1, 1)
data_8 -= data_8.mean(axis=1).reshape(-1, 1)
data_9 -= data_9.mean(axis=1).reshape(-1, 1)

# %%
plt.figure(0)
plt.plot(data_7[0])
plt.figure(1)
plt.plot(data_8[0])
plt.figure(2)
plt.plot(data_9[0])
plt.figure(3)
plt.plot(np.hstack((data_7, data_8, data_9))[0])

# %%
data
# Out:
# array([[31.,  1.],
#        [11.,  1.],
#        [11.,  1.],
#        [31.,  2.],
#        [21.,  1.],
#        [41.,  3.],
#        [21.,  1.],
#        [41.,  4.],
#        [11.,  1.],
#        [21.,  1.],
#        [41.,  5.],
#        [21.,  1.],
#        [11.,  1.],
#        [31.,  5.],
#        [41.,  6.],
#        [31.,  4.],
#        [41.,  6.],
#        [21.,  1.],
#        [41.,  3.],
#        [31.,  4.],
#        [11.,  1.],
#        [31.,  3.],
#        [21.,  1.],
#        [11.,  1.],
#        [41.,  6.],
#        [31.,  5.],
#        [31.,  5.],
#        [21.,  2.],
#        [21.,  1.],
#        [41.,  6.],
#        [11.,  1.],
#        [11.,  1.],
#        [31.,  6.],
#        [41.,  6.],
#        [21.,  1.],
#        [11.,  1.],
#        [31.,  5.],
#        [11.,  1.],
#        [21.,  2.],
#        [41.,  6.]])
